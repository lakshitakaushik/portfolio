# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitakaushik/portfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kurtosis, skew

# %%
df= pd.read_excel('/content/final dataset.xlsx')
df.head()
# Out:
#   Company name        Date  Open Price  Close Price
# 0     Axis Bank 2023-12-29     1106.75      1102.95
# 1     Axis Bank 2023-12-28     1109.85      1108.00
# 2     Axis Bank 2023-12-27     1093.95      1106.55
# 3     Axis Bank 2023-12-26     1089.05      1094.25
# 4     Axis Bank 2023-12-22     1097.95      1087.85

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.columns
# Out:
# Index(['Company name ', 'Date', 'Open Price', 'Close Price'], dtype='object')

# %%
grouped_df = df.groupby('Company name ')

# %%
def kurtosis_value(series):
  return kurtosis(series)

def skewness_value(series):
  return skew(series)
descript=grouped_df['Open Price'].agg(['count','mean','std','min','max','var'])
print(descript)
# Out:
#                       count         mean         std      min      max  \
# Company name
# Axis Bank              4711   760.505010  348.095644   177.80  2037.00
# Bandhan Bank           1427   362.660617  125.949653   163.95   727.00
# Bank of Baroda         4711   341.016239  278.286488    36.30  1117.10
# Bank of India          4711   190.517788  121.538678    31.00   580.00
# Bank of Maharashtra    4711    35.038053   16.094488     8.35    94.90
# CSB Bank               4053    70.782490   45.015252    10.35   245.40
# Canara Bank            4711   296.564976  118.740852    76.60   836.00
# Central Bank           4053    70.782490   45.015252    10.35   245.40
# City Union Bank        4053    70.782490   45.015252    10.35   245.40
# DCB Bank               8965    70.244930   51.833758     7.60   242.05
# DHANLAXMI BANK          784    61.760765   17.616373    29.90   109.94
# EQUITAS BANK             34    70.560882    6.900978    66.99   108.41
# ...
